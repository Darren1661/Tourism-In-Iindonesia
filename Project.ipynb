# %%
import pandas as pd

# %% [markdown]
# Gather Data

# %%
package_df = pd.read_csv("D:\BINUS\Bank Soal Data Warehouse\csv project\package_tourism.csv")
package_df.head()
# Out:
#    Package     City         Place_Tourism1      Place_Tourism2  \
# 0        1  Jakarta      Pasar Tanah Abang        Taman Ayodya
# 1        2  Jakarta      Pasar Tanah Abang  Pasar Taman Puring
# 2        3  Jakarta  Perpustakaan Nasional               Monas
# 3        4  Jakarta           Pulau Tidung      Pulau Bidadari
# 4        5  Jakarta  Museum Satria Mandala       Museum Wayang
#
#           Place_Tourism3                                     Place_Tourism4  \
# 0         Museum Tekstil                                                NaN
# 1   Pasar Petak Sembilan                                                NaN
# 2        Masjid Istiqlal                                                NaN
# 3             Pulau Pari                                      Pulau Pramuka
# 4  Museum Bahari Jakarta  Museum Macan (Modern and Contemporary Art in N...
#
#   Place_Tourism5
# 0            NaN
# 1            NaN
# 2            NaN
# 3  Pulau Pelangi
# 4            NaN

# %%
ratingtourism_df = pd.read_csv("D:\\BINUS\\Bank Soal Data Warehouse\\csv project\\rating_tourism.csv")
ratingtourism_df.head()
# Out:
#    User_Id  Place_Id  Place_Ratings
# 0        1       179              3
# 1        1       344              2
# 2        1         5              5
# 3        1       373              3
# 4        1       101              4

# %%
tourismwithid_df = pd.read_csv("D:\\BINUS\\Bank Soal Data Warehouse\\csv project\\tourism_with_id.csv")
tourismwithid_df.sample(20)
# Out:
#      Place_Id                      Place_Name  \
# 44         45     Jakarta Aquarium dan Safari
# 113       114           The Lost World Castle
# 237       238               Gunung Manglayang
# 8           9                Pelabuhan Marina
# 149       150             Wisata Kraton Jogja
# 403       404                   Kenjeran Park
# 86         87      Sindu Kusuma Edupark (SKE)
# 63         64  Museum Sasmita Loka Ahmad Yani
# 25         26                  Pecinan Glodok
# 80         81               Mall Thamrin City
# 12         13                   Pulau Pramuka
# 1           2                        Kota Tua
# 345       346             Indonesia Kaya Park
# 298       299        Sendang Geulis Kahuripan
# 228       229                     Rabbit Town
# 292       293                     Taman Badak
# 81         82           Museum Satria Mandala
# 318       319          Kawah Rengganis Cibuni
# 130       131                    Watu Lumbung
# ...

# %%
user_df = pd.read_csv("D:\\BINUS\\Bank Soal Data Warehouse\\csv project\\user.csv")
user_df.head()
# Out:
#    User_Id                   Location  Age
# 0        1      Semarang, Jawa Tengah   20
# 1        2         Bekasi, Jawa Barat   21
# 2        3        Cirebon, Jawa Barat   23
# 3        4         Bekasi, Jawa Barat   21
# 4        5  Lampung, Sumatera Selatan   20

# %% [markdown]
# assesing data

# %%
package_df.info()
package_df.isna().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Package         100 non-null    int64
#  1   City            100 non-null    object
#  2   Place_Tourism1  100 non-null    object
#  3   Place_Tourism2  100 non-null    object
#  4   Place_Tourism3  100 non-null    object
#  5   Place_Tourism4  66 non-null     object
#  6   Place_Tourism5  39 non-null     object
# dtypes: int64(1), object(6)
# memory usage: 5.6+ KB
# Package            0
# City               0
# Place_Tourism1     0
# Place_Tourism2     0
# Place_Tourism3     0
# Place_Tourism4    34
# Place_Tourism5    61
# dtype: int64

# %%
ratingtourism_df.info()
ratingtourism_df.isna().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   User_Id        10000 non-null  int64
#  1   Place_Id       10000 non-null  int64
#  2   Place_Ratings  10000 non-null  int64
# dtypes: int64(3)
# memory usage: 234.5 KB
# User_Id          0
# Place_Id         0
# Place_Ratings    0
# dtype: int64

# %%
tourismwithid_df.info()
tourismwithid_df.isna().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 437 entries, 0 to 436
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Place_Id      437 non-null    int64
#  1   Place_Name    437 non-null    object
#  2   Description   437 non-null    object
#  3   Category      437 non-null    object
#  4   City          437 non-null    object
#  5   Price         437 non-null    int64
#  6   Rating        437 non-null    float64
#  7   Time_Minutes  205 non-null    float64
#  8   Coordinate    437 non-null    object
#  9   Lat           437 non-null    float64
#  10  Long          437 non-null    float64
#  11  Unnamed: 11   0 non-null      float64
#  12  Unnamed: 12   437 non-null    int64
# dtypes: float64(5), int64(3), object(5)
# memory usage: 44.5+ KB
# Place_Id          0
# Place_Name        0
# Description       0
# Category          0
# City              0
# Price             0
# Rating            0
# ...

# %%
user_df.info()
user_df.isna().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   User_Id   300 non-null    int64
#  1   Location  300 non-null    object
#  2   Age       300 non-null    int64
# dtypes: int64(2), object(1)
# memory usage: 7.2+ KB
# User_Id     0
# Location    0
# Age         0
# dtype: int64

# %%
print('Dupe package : ', package_df.duplicated().sum())
print('Dupe rating turis : ', ratingtourism_df.duplicated().sum())
print('Dupe turiswithid : ', tourismwithid_df.duplicated().sum())
print('Dupe user : ', user_df.duplicated().sum())
# Out:
# Dupe package :  0
# Dupe rating turis :  79
# Dupe turiswithid :  0
# Dupe user :  0

# %%
package_df[['Place_Tourism4', 'Place_Tourism5']] = package_df[['Place_Tourism4', 'Place_Tourism5']].fillna('-')
print(package_df[['Place_Tourism4', 'Place_Tourism5']])
# Out:
#                                        Place_Tourism4  \
# 0                                                   -
# 1                                                   -
# 2                                                   -
# 3                                       Pulau Pramuka
# 4   Museum Macan (Modern and Contemporary Art in N...
# ..                                                ...
# 95                    Taman Ekspresi Dan Perpustakaan
# 96                        Food Junction Grand Pakuwon
# 97                                      Taman Bungkul
# 98                                Museum Mpu Tantular
# 99                               Kebun Bibit Wonorejo
#
#                       Place_Tourism5
# 0                                  -
# 1                                  -
# 2                                  -
# 3                      Pulau Pelangi
# 4                                  -
# ..                               ...
# 95           Museum De Javasche Bank
# ...

# %%
package_df.head()
# Out:
#    Package     City         Place_Tourism1      Place_Tourism2  \
# 0        1  Jakarta      Pasar Tanah Abang        Taman Ayodya
# 1        2  Jakarta      Pasar Tanah Abang  Pasar Taman Puring
# 2        3  Jakarta  Perpustakaan Nasional               Monas
# 3        4  Jakarta           Pulau Tidung      Pulau Bidadari
# 4        5  Jakarta  Museum Satria Mandala       Museum Wayang
#
#           Place_Tourism3                                     Place_Tourism4  \
# 0         Museum Tekstil                                                  -
# 1   Pasar Petak Sembilan                                                  -
# 2        Masjid Istiqlal                                                  -
# 3             Pulau Pari                                      Pulau Pramuka
# 4  Museum Bahari Jakarta  Museum Macan (Modern and Contemporary Art in N...
#
#   Place_Tourism5
# 0              -
# 1              -
# 2              -
# 3  Pulau Pelangi
# 4              -

# %%
tourismwithid_df.drop(['Unnamed: 11', 'Unnamed: 12','Description','Coordinate'], axis=1, inplace=True)
tourismwithid_df.sample(10)
# Out:
#      Place_Id                                 Place_Name            Category  \
# 418       419                      Monumen Tugu Pahlawan              Budaya
# 303       304                              Situ Cileunca          Cagar Alam
# 287       288                          Masjid Salman ITB       Tempat Ibadah
# 242       243                      Kampung Korea Bandung              Budaya
# 9          10                               Pulau Tidung              Bahari
# 60         61                            Tugu Proklamasi              Budaya
# 67         68                       Pasar Petak Sembilan  Pusat Perbelanjaan
# 36         37                    Bumi Perkemahan Cibubur       Taman Hiburan
# 436       437  Gereja Perawan Maria Tak Berdosa Surabaya       Tempat Ibadah
# 412       413              Museum TNI AL Loka Jala Crana              Budaya
#
#          City   Price  Rating  Time_Minutes       Lat        Long
# ...

# %%
rating_turismwithid_df = pd.merge(
    left=ratingtourism_df,
    right=tourismwithid_df,
    how="left",
    left_on="Place_Id",
    right_on="Place_Id"
)
rating_turismwithid_df.head()
# Out:
#    User_Id  Place_Id  Place_Ratings                     Place_Name  \
# 0        1       179              3                Candi Ratu Boko
# 1        1       344              2                  Pantai Marina
# 2        1         5              5       Atlantis Water Adventure
# 3        1       373              3         Museum Kereta Ambarawa
# 4        1       101              4  Kampung Wisata Sosro Menduran
#
#         Category        City  Price  Rating  Time_Minutes       Lat  \
# 0         Budaya  Yogyakarta  75000     4.6          90.0 -7.770542
# 1         Bahari    Semarang   3000     4.1           NaN -6.948877
# 2  Taman Hiburan     Jakarta  94000     4.5          60.0 -6.124190
# 3         Budaya    Semarang  10000     4.5          60.0 -7.264599
# 4         Budaya  Yogyakarta      0     4.0           NaN -7.792190
#
#          Long
# 0  110.489416
# 1  110.389329
# 2  106.839134
# 3  110.404602
# 4  110.362151

# %%
finalmergeset_df = pd.merge(
    left=rating_turismwithid_df,
    right=user_df,
    how="left",
    left_on="User_Id",
    right_on="User_Id"
)
finalmergeset_df.head(100)
# Out:
#     User_Id  Place_Id  Place_Ratings                           Place_Name  \
# 0         1       179              3                      Candi Ratu Boko
# 1         1       344              2                        Pantai Marina
# 2         1         5              5             Atlantis Water Adventure
# 3         1       373              3               Museum Kereta Ambarawa
# 4         1       101              4        Kampung Wisata Sosro Menduran
# ..      ...       ...            ...                                  ...
# 95        4       409              3                          Rumah Batik
# 96        4        88              3  Museum Benteng Vredeburg Yogyakarta
# 97        4         4              4    Taman Mini Indonesia Indah (TMII)
# 98        4       377              3                       La Kana Chapel
# 99        4        43              5                      The Escape Hunt
#
#          Category        City  Price  Rating  Time_Minutes       Lat  \
# ...

# %%
finalmergeset_df.to_csv('projectku.csv', index=False)
